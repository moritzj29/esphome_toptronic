# %%
import re
import pandas as pd
import openpyxl
from pathlib import Path
from tabulate import tabulate

# %%
# CAN-ID mapping
CAN_ID_MAP = {
    "0x1FC017FF".lower(): ("WEZ", 2),
    "0x1FC00FFF".lower(): ("WEZ", 1),
}

# %%
log_file = "logs_esp32-eth02_run.txt"  # path to your log file
excel_file = "TTE-GW-Modbus-datapoints_edited.xlsx"  # path to your input Excel file

log_file = Path(log_file)

# %%
def extract_datapoints(logfile):
    """Extract DatapointId + CAN ID pairs from log file ([NEW] lines only)."""
    results = []
    with open(logfile, "r") as f:
        for i, line in enumerate(f):
            if "[NEW]" not in line and "[EXS]" not in line:
                continue
            can_match = re.search(r"Can-ID:\s+(0x[0-9A-Fa-f]+)", line)
            dp_match = re.search(r"Datapoint:\s+0x[0-9A-Fa-f]+\s+\((\d+)\)", line)
            group_match = re.search(r"function_group:\s+0x[0-9A-Fa-f]+\s+\((\d+)\)", line)
            number_match = re.search(r"function_number:\s+0x[0-9A-Fa-f]+\s+\((\d+)\)", line)

            if can_match and dp_match and group_match and number_match:
                can_id = can_match.group(1).upper()
                datapoint = int(dp_match.group(1))
                group = int(group_match.group(1))
                number = int(number_match.group(1))
                if can_id.lower() in CAN_ID_MAP.keys():
                    unit_name, unit_id = CAN_ID_MAP.get(can_id.lower(), can_id)
                else:
                    unit_name = can_id
                    unit_id = -1
                results.append((i, unit_name, unit_id, group, number, datapoint))
    return results

results = extract_datapoints(log_file)
results_df = pd.DataFrame(results, columns=["Line", "UnitName", "UnitId", "FunctionGroup", "FunctionNumber", "DatapointId"])
results_df.drop_duplicates(subset=["UnitName", "UnitId", "FunctionGroup", "FunctionNumber", "DatapointId"], inplace=True)
results_df
# Out:
#      Line    UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId
# 0     101         WEZ       2              2               0          504
# 1     151         WEZ       2              2               0            4
# 2     160         WEZ       1              1               0          500
# 5     252         WEZ       1              1               0         7036
# 6     253         WEZ       1              1               1          500
# ..    ...         ...     ...            ...             ...          ...
# 241  1708  0X1E8017FF      -1             10               1         2082
# 248  1753         WEZ       1              1               1         1002
# 253  1773         WEZ       2             10               1         9075
# 259  1828         WEZ       2             10               1        20053
# 287  1988         WEZ       1             10               1        20050
#
# [146 rows x 6 columns]

# %%
results_df.sort_values(by=["DatapointId"])
# Out:
#      Line    UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId
# 234  1593         WEZ       2              0               0            0
# 64    631         WEZ       1              0               0            0
# 48    569         WEZ       1             60             254            0
# 58    605         WEZ       1             60             254            1
# 50    577         WEZ       1              1               1            1
# ..    ...         ...     ...            ...             ...          ...
# 220  1491         WEZ       2             10               1        23085
# 175  1224  0X1E800FFF      -1             10               1        29050
# 211  1419         WEZ       1              0               0        38003
# 135  1051         WEZ       1              0               0        38012
# 221  1492         WEZ       1              0               0        38013
#
# [146 rows x 6 columns]

# %%
df_ref = pd.read_excel(excel_file, sheet_name=1)
df_ref
# Out:
#        Register Address UnitName  UnitId  FunctionGroup  FunctionNumber  \
# 0                     1      SOL      65             22               0
# 1                     2      SOL      65             22               1
# 2                     3      SOL      65             22               1
# 3                     4      SOL      65             22               1
# 4                     5      SOL      65             22               1
# ...                 ...      ...     ...            ...             ...
# 30929             31767       PS     143             21               0
# 30930             31768       PS     142             21               0
# 30931             31769       PS     142             21               0
# 30932             31770       PS     143             21               0
# 30933             31771       PS     143             21               0
#
#        DatapointId                            DatapointName  Type TypeName  \
# 0               14                TKO1 Kollektor Temperatur     1      S16
# 1               14                TKO2 Kollektor Temperatur     1      S16
# 2             2034              Gesamtertrag Kollektor_high     2      S32
# 3             2034               Gesamtertrag Kollektor_low     1      S32
# 4             2030                Kollektorleistung aktuell     1      S16
# ...            ...                                      ...   ...      ...
# 30929         6055  Sollw.-Reduktion Puffer-Sollwert Kühlen     1      S16
# 30930         6033   Puffer-Sollwert bei Konstantanf.Heizen     1      S16
# 30931         6056  Puffer-Sollwert bei Konstantanf. Kühlen     1      S16
# 30932         6033   Puffer-Sollwert bei Konstantanf.Heizen     1      S16
# 30933         6056  Puffer-Sollwert bei Konstantanf. Kühlen     1      S16
#
#       Decimal  ... Text 22 Text 23  Text 24 Text 25  Text 26 Text 27 Text 28  \
# 0           1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1           1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 2           0  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 3           0  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 4           1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# ...       ...  ...     ...     ...      ...     ...      ...     ...     ...
# 30929       1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 30930       1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 30931       1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 30932       1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 30933       1  ...     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
#       Text 29 Text 30 Text 31
# 0         NaN     NaN     NaN
# 1         NaN     NaN     NaN
# 2         NaN     NaN     NaN
# 3         NaN     NaN     NaN
# 4         NaN     NaN     NaN
# ...       ...     ...     ...
# 30929     NaN     NaN     NaN
# 30930     NaN     NaN     NaN
# 30931     NaN     NaN     NaN
# 30932     NaN     NaN     NaN
# 30933     NaN     NaN     NaN
#
# [30934 rows x 50 columns]

# %%
df_test = pd.merge(results_df, df_ref, on=["UnitName", "UnitId", "FunctionGroup", "FunctionNumber", "DatapointId"], how="right", suffixes=('_log', '_ref'))
df_test
# Out:
#        Line UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId  \
# 0       NaN      SOL      65             22               0           14
# 1       NaN      SOL      65             22               1           14
# 2       NaN      SOL      65             22               1         2034
# 3       NaN      SOL      65             22               1         2034
# 4       NaN      SOL      65             22               1         2030
# ...     ...      ...     ...            ...             ...          ...
# 30929   NaN       PS     143             21               0         6055
# 30930   NaN       PS     142             21               0         6033
# 30931   NaN       PS     142             21               0         6056
# 30932   NaN       PS     143             21               0         6033
# 30933   NaN       PS     143             21               0         6056
#
#        Register Address                            DatapointName  Type  \
# 0                     1                TKO1 Kollektor Temperatur     1
# 1                     2                TKO2 Kollektor Temperatur     1
# 2                     3              Gesamtertrag Kollektor_high     2
# 3                     4               Gesamtertrag Kollektor_low     1
# 4                     5                Kollektorleistung aktuell     1
# ...                 ...                                      ...   ...
# 30929             31767  Sollw.-Reduktion Puffer-Sollwert Kühlen     1
# 30930             31768   Puffer-Sollwert bei Konstantanf.Heizen     1
# 30931             31769  Puffer-Sollwert bei Konstantanf. Kühlen     1
# 30932             31770   Puffer-Sollwert bei Konstantanf.Heizen     1
# 30933             31771  Puffer-Sollwert bei Konstantanf. Kühlen     1
#
#       TypeName  ... Text 22 Text 23 Text 24  Text 25 Text 26  Text 27 Text 28  \
# 0          S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1          S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 2          S32  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 3          S32  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 4          S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# ...        ...  ...     ...     ...     ...      ...     ...      ...     ...
# 30929      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 30930      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 30931      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 30932      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 30933      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
#
#       Text 29 Text 30 Text 31
# 0         NaN     NaN     NaN
# 1         NaN     NaN     NaN
# 2         NaN     NaN     NaN
# 3         NaN     NaN     NaN
# 4         NaN     NaN     NaN
# ...       ...     ...     ...
# 30929     NaN     NaN     NaN
# 30930     NaN     NaN     NaN
# 30931     NaN     NaN     NaN
# 30932     NaN     NaN     NaN
# 30933     NaN     NaN     NaN
#
# [30934 rows x 51 columns]

# %%
df_out = df_test[~df_test["Line"].isna()].sort_values(by=["DatapointId"])
df_out
# Out:
#          Line UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId  \
# 1376    631.0      WEZ       1              0               0            0
# 1419    569.0      WEZ       1             60             254            0
# 1509   1593.0      WEZ       2              0               0            0
# 1410    577.0      WEZ       1              1               1            1
# 1420    605.0      WEZ       1             60             254            1
# ...       ...      ...     ...            ...             ...          ...
# 1463    869.0      WEZ       1             10               1        23085
# 1596   1491.0      WEZ       2             10               1        23085
# 26704  1419.0      WEZ       1              0               0        38003
# 26707  1051.0      WEZ       1              0               0        38012
# 26708  1492.0      WEZ       1              0               0        38013
#
#        Register Address                  DatapointName  Type TypeName  ...  \
# 1376               1477           AF1 - Aussenfühler 1     1      S16  ...
# 1419               1520  Sollwert für Heizkreisbetrieb     1      S16  ...
# 1509               1610           AF1 - Aussenfühler 1     1      S16  ...
# 1410               1511                       Raum-Ist     1      S16  ...
# 1420               1521   Sollwert für Speicherbetrieb     1      S16  ...
# ...                 ...                            ...   ...      ...  ...
# 1463               1564       Emissionstest aktivieren     1       U8  ...
# 1596               1697       Emissionstest aktivieren     1       U8  ...
# 26704             27542             SG Mindestleistung     1      U16  ...
# 26707             27545      Smart Grid über Systembus     1       U8  ...
# 26708             27546   Auslöser Smart Grid Funktion     1       U8  ...
#
#       Text 22 Text 23 Text 24  Text 25 Text 26  Text 27 Text 28 Text 29  \
# 1376      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1419      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1509      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1410      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1420      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# ...       ...     ...     ...      ...     ...      ...     ...     ...
# 1463      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1596      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26704     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26707     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26708     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
#       Text 30 Text 31
# 1376      NaN     NaN
# 1419      NaN     NaN
# 1509      NaN     NaN
# 1410      NaN     NaN
# 1420      NaN     NaN
# ...       ...     ...
# 1463      NaN     NaN
# 1596      NaN     NaN
# 26704     NaN     NaN
# 26707     NaN     NaN
# 26708     NaN     NaN
#
# [115 rows x 51 columns]

# %%
df_wez1 = df_out[(df_out["UnitName"] == "WEZ") & (df_out["UnitId"] == 1)]
df_wez1
# Out:
#          Line UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId  \
# 1376    631.0      WEZ       1              0               0            0
# 1419    569.0      WEZ       1             60             254            0
# 1410    577.0      WEZ       1              1               1            1
# 1420    605.0      WEZ       1             60             254            1
# 1409    573.0      WEZ       1              1               0            1
# ...       ...      ...     ...            ...             ...          ...
# 26629  1199.0      WEZ       1             10               1        23008
# 1463    869.0      WEZ       1             10               1        23085
# 26704  1419.0      WEZ       1              0               0        38003
# 26707  1051.0      WEZ       1              0               0        38012
# 26708  1492.0      WEZ       1              0               0        38013
#
#        Register Address                  DatapointName  Type TypeName  ...  \
# 1376               1477           AF1 - Aussenfühler 1     1      S16  ...
# 1419               1520  Sollwert für Heizkreisbetrieb     1      S16  ...
# 1410               1511                       Raum-Ist     1      S16  ...
# 1420               1521   Sollwert für Speicherbetrieb     1      S16  ...
# 1409               1510                       Raum-Ist     1      S16  ...
# ...                 ...                            ...   ...      ...  ...
# 26629             27467      JAZ Jahresarbeitszahl WEZ     1       U8  ...
# 1463               1564       Emissionstest aktivieren     1       U8  ...
# 26704             27542             SG Mindestleistung     1      U16  ...
# 26707             27545      Smart Grid über Systembus     1       U8  ...
# 26708             27546   Auslöser Smart Grid Funktion     1       U8  ...
#
#       Text 22 Text 23 Text 24  Text 25 Text 26  Text 27 Text 28 Text 29  \
# 1376      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1419      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1410      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1420      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1409      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# ...       ...     ...     ...      ...     ...      ...     ...     ...
# 26629     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 1463      NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26704     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26707     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
# 26708     NaN     NaN     NaN      NaN     NaN      NaN     NaN     NaN
#
#       Text 30 Text 31
# 1376      NaN     NaN
# 1419      NaN     NaN
# 1410      NaN     NaN
# 1420      NaN     NaN
# 1409      NaN     NaN
# ...       ...     ...
# 26629     NaN     NaN
# 1463      NaN     NaN
# 26704     NaN     NaN
# 26707     NaN     NaN
# 26708     NaN     NaN
#
# [89 rows x 51 columns]

# %%
print("".join(df_wez1[["Register Address", "DatapointName"]].apply(lambda x : "{}, # {}\r\n".format(*x.astype(str)),1)))
# Out:
# 1477, # AF1 - Aussenfühler 1
# 1520, # Sollwert für Heizkreisbetrieb
# 1511, # Raum-Ist
# 1521, # Sollwert für Speicherbetrieb
# 1510, # Raum-Ist
# 1515, # Vorlauf-Ist
# 1514, # Vorlauf-Ist
# 1513, # Vorlauf-Ist
# 1500, # Warmwasser-Ist SF
# 18725, # Wärmeerzeuger-Ist
# 18742, # Rücklauftemperatur Wärmeerzeuger
# 1525, # WEZ-Temperatur
# 1529, # Heizung Sollwert
# 18740, # Drehzahl Hauptpumpe
# 1530, # Speicher Sollwert
# 1531, # WEZ Sollwert
# 1534, # Fehlercode vom Automaten
# 1536, # WEZ-Leistung
# 1537, # Absolute Leistung
# 1539, # WEZ-Status
# 1540, # Betriebsstatus
# 27490, # Coefficient of Performance
# 27491, # Sondenvorlauf-/Ansaugtemp.
# 27492, # Sondenrücklauf-/Verdampferoberfl.temp.
# 18760, # Anlage Vorlauftemperatur Heizen
# 19868, # Anlage Vorlauftemperatur WW
# 1494, # Raum-Soll
# 1493, # Raum-Soll
# 19563, # Vorlauf-Soll
# 19562, # Vorlauf-Soll
# 1499, # Warmwasser-Soll
# 18724, # Wärmeerzeuger-Soll
# 18769, # Sollwert Leistung Wärmeerzeuger
# 18745, # Sollwert Leistung Wärmeerzeuger
# 18767, # Sollwert Leistung Wärmeerzeuger
# 19706, # Pumpe
# 19707, # Pumpe
# 19659, # Mischer
# 19658, # Mischer
# 18739, # Pumpe Wärmeerzeuger
# 18757, # Pumpe Wärmeerzeuger
# 19754, # SLP Warmwasser-Ladepumpe
# 18761, # Anlagetemp.Soll Heizen aktuell
# 18762, # Anlagetemp.Soll WW aktuell
# 27534, # Sammelstörung Störmeldeausgang
# 18768, # 0 - 100% aktuelle Anf. an WE
# 18770, # 0 - 100% aktuelle Anf. an WE
# 1501, # Status Heizkreisregelung
# 1502, # Status Heizkreisregelung
# 1504, # Status Warmwasserregelung
# 18722, # Status Wärmeerzeugerregelung
# 19872, # Führungs-WEZ
# 27548, # Führungs-WEZ
# 27510, # Regelstrategie
# 1479, # Betriebswahl Heizung
# 1478, # Betriebswahl Heizung
# 1483, # Normal-Raumtemperatur Heizbetrieb
# 1481, # Normal-Raumtemperatur Heizbetrieb
# 1484, # Spar-Raumtemperatur Heizbetrieb
# 1482, # Spar-Raumtemperatur Heizbetrieb
# 1486, # Spar-Raumtemperatur Heizbetrieb
# 1496, # Betriebswahl Warmwasser
# 1497, # Normal-Warmwassertemperatur
# 1498, # Spar-Warmwassertemperatur
# 1490, # Vorlauf Soll Konstantanf. Heizen
# 19482, # Vorlauf Soll Konstantanf. Kühlen
# 1561, # Betriebswahl Wärmeerzeuger
# 18738, # Wasserdruck
# 18723, # FA-Status
# 18726, # Modulation
# 18737, # Betriebsmeldung
# 27536, # Verfügbare el. Leistung gedämpft
# 1546, # MK1 HW-Ausgang
# 1547, # YK1+ HW-Ausgang
# 1548, # YK1- HW-Ausgang
# 1551, # VA1 HW-Ausgang
# 1552, # VA2 HW-Ausgang
# 27537, # Status Smart Grid
# 31741, # Status Smart Grid
# 27538, # Status Sollwert Erhöhung/Reduktion
# 19049, # Info 1 - vermutlich AVF W (VE1)
# 19050, # Info 2 - vermutlich AVF H (VE2)
# 25611, # Aktuelle elektr. Leistungsaufnahme WEZ
# 25612, # Aktuelle therm. Leistungsaufnahme WEZ
# 27467, # JAZ Jahresarbeitszahl WEZ
# 1564, # Emissionstest aktivieren
# 27542, # SG Mindestleistung
# 27545, # Smart Grid über Systembus
# 27546, # Auslöser Smart Grid Funktion

# %%
df_wez2 = df_out[(df_out["UnitName"] == "WEZ") & (df_out["UnitId"] == 2)]
df_wez2
# Out:
#          Line UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId  \
# 1509   1593.0      WEZ       2              0               0            0
# 1532    151.0      WEZ       2              2               0            4
# 26715   617.0      WEZ       2              2               0            6
# 17948   361.0      WEZ       2             10               1            7
# 17965   914.0      WEZ       2             10               1            8
# 1568   1111.0      WEZ       2             60             254           30
# 1569   1115.0      WEZ       2             60             254           31
# 26722  1180.0      WEZ       2             60             254           45
# 1531    358.0      WEZ       2              2               0         1004
# 17947   888.0      WEZ       2             10               1         1007
# 18919  1324.0      WEZ       2              2               0         1066
# 1528    903.0      WEZ       2              2               0         5050
# 1593   1773.0      WEZ       2             10               1         9075
# 17949  1116.0      WEZ       2             10               1        20052
# 17960  1828.0      WEZ       2             10               1        20053
# 1578   1312.0      WEZ       2              0               0        21031
# 1579   1313.0      WEZ       2              0               0        21032
# 1580   1314.0      WEZ       2              0               0        21033
# 1582   1315.0      WEZ       2              0               0        21035
# 1584   1330.0      WEZ       2              0               0        21037
# 18216   865.0      WEZ       2              0               0        21120
# 18217   867.0      WEZ       2              0               0        21121
# 24777  1166.0      WEZ       2             10               1        23002
# 24778  1170.0      WEZ       2             10               1        23003
# 26630  1221.0      WEZ       2             10               1        23008
# 1596   1491.0      WEZ       2             10               1        23085
#
#        Register Address                           DatapointName  Type  \
# 1509               1610                    AF1 - Aussenfühler 1     1
# 1532               1633                       Warmwasser-Ist SF     1
# 26715             27553                      Warmwasser-Ist SF2     1
# 17948             18786                       Wärmeerzeuger-Ist     1
# 17965             18803        Rücklauftemperatur Wärmeerzeuger     1
# 1568               1669                            WEZ-Leistung     1
# 1569               1670                       Absolute Leistung     1
# 26722             27560              Coefficient of Performance     1
# 1531               1632                         Warmwasser-Soll     1
# 17947             18785                      Wärmeerzeuger-Soll     1
# 18919             19757                SLP Warmwasser-Ladepumpe     1
# 1528               1629                 Betriebswahl Warmwasser     1
# 1593               1694              Betriebswahl Wärmeerzeuger     1
# 17949             18787                              Modulation     1
# 17960             18798                         Betriebsmeldung     1
# 1578               1679                          MK1 HW-Ausgang     1
# 1579               1680                         YK1+ HW-Ausgang     1
# 1580               1681                         YK1- HW-Ausgang     1
# 1582               1683                          SLP HW-Ausgang     1
# 1584               1685                          VA2 HW-Ausgang     1
# 18216             19054      Info 1 - vermutlich DF1-1 (21-015)     1
# 18217             19055      Info 2 - vermutlich DF1-2 (21-018)     1
# 24777             25615  Aktuelle elektr. Leistungsaufnahme WEZ     1
# 24778             25616   Aktuelle therm. Leistungsaufnahme WEZ     1
# 26630             27468               JAZ Jahresarbeitszahl WEZ     1
# 1596               1697                Emissionstest aktivieren     1
#
#       TypeName  ... Text 22 Text 23 Text 24  Text 25 Text 26  Text 27 Text 28  \
# 1509       S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1532       S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 26715      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 17948      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 17965      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1568        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1569        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 26722       U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1531       S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 17947      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 18919       U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1528      LIST  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1593      LIST  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 17949       U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 17960       U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1578        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1579        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1580        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1582        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1584        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 18216      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 18217      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 24777      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 24778      S16  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 26630       U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1596        U8  ...     NaN     NaN     NaN      NaN     NaN      NaN     NaN
#
#       Text 29 Text 30 Text 31
# 1509      NaN     NaN     NaN
# 1532      NaN     NaN     NaN
# 26715     NaN     NaN     NaN
# 17948     NaN     NaN     NaN
# 17965     NaN     NaN     NaN
# 1568      NaN     NaN     NaN
# 1569      NaN     NaN     NaN
# 26722     NaN     NaN     NaN
# 1531      NaN     NaN     NaN
# 17947     NaN     NaN     NaN
# 18919     NaN     NaN     NaN
# 1528      NaN     NaN     NaN
# 1593      NaN     NaN     NaN
# 17949     NaN     NaN     NaN
# 17960     NaN     NaN     NaN
# 1578      NaN     NaN     NaN
# 1579      NaN     NaN     NaN
# 1580      NaN     NaN     NaN
# 1582      NaN     NaN     NaN
# 1584      NaN     NaN     NaN
# 18216     NaN     NaN     NaN
# 18217     NaN     NaN     NaN
# 24777     NaN     NaN     NaN
# 24778     NaN     NaN     NaN
# 26630     NaN     NaN     NaN
# 1596      NaN     NaN     NaN
#
# [26 rows x 51 columns]

# %%
print("".join(df_wez2[["Register Address", "DatapointName"]].apply(lambda x : "{}, # {}\r\n".format(*x.astype(str)),1)))
# Out:
# 1610, # AF1 - Aussenfühler 1
# 1633, # Warmwasser-Ist SF
# 27553, # Warmwasser-Ist SF2
# 18786, # Wärmeerzeuger-Ist
# 18803, # Rücklauftemperatur Wärmeerzeuger
# 1669, # WEZ-Leistung
# 1670, # Absolute Leistung
# 27560, # Coefficient of Performance
# 1632, # Warmwasser-Soll
# 18785, # Wärmeerzeuger-Soll
# 19757, # SLP Warmwasser-Ladepumpe
# 1629, # Betriebswahl Warmwasser
# 1694, # Betriebswahl Wärmeerzeuger
# 18787, # Modulation
# 18798, # Betriebsmeldung
# 1679, # MK1 HW-Ausgang
# 1680, # YK1+ HW-Ausgang
# 1681, # YK1- HW-Ausgang
# 1683, # SLP HW-Ausgang
# 1685, # VA2 HW-Ausgang
# 19054, # Info 1 - vermutlich DF1-1 (21-015)
# 19055, # Info 2 - vermutlich DF1-2 (21-018)
# 25615, # Aktuelle elektr. Leistungsaufnahme WEZ
# 25616, # Aktuelle therm. Leistungsaufnahme WEZ
# 27468, # JAZ Jahresarbeitszahl WEZ
# 1697, # Emissionstest aktivieren

# %%
pd.set_option("display.max_rows", None)

# %%
display(df_out.sort_values(by=["DatapointId"])[["UnitName", "UnitId", "FunctionGroup", "FunctionNumber", "DatapointId", "DatapointName", "Register Address", "FunctionGroup name", "Function name"]])
# Out:
#       UnitName  UnitId  FunctionGroup  FunctionNumber  DatapointId  \
# 1376       WEZ       1              0               0            0
# 1419       WEZ       1             60             254            0
# 1509       WEZ       2              0               0            0
# 1410       WEZ       1              1               1            1
# 1420       WEZ       1             60             254            1
# 1409       WEZ       1              1               0            1
# 1414       WEZ       1              1               2            2
# 1413       WEZ       1              1               1            2
# 1412       WEZ       1              1               0            2
# 1532       WEZ       2              2               0            4
# 1399       WEZ       1              2               0            4
# 26715      WEZ       2              2               0            6
# 17887      WEZ       1             10               1            7
# 17948      WEZ       2             10               1            7
# 17965      WEZ       2             10               1            8
# 17904      WEZ       1             10               1            8
# 1424       WEZ       1             60             254           17
# 1428       WEZ       1             60             254           22
# 17902      WEZ       1             10               1           22
# 1429       WEZ       1             60             254           23
# 1430       WEZ       1             60             254           24
# 1433       WEZ       1             60             254           27
# 1435       WEZ       1             60             254           30
# 1568       WEZ       2             60             254           30
# 1569       WEZ       2             60             254           31
# 1436       WEZ       1             60             254           31
# 1438       WEZ       1             60             254           33
# 1439       WEZ       1             60             254           34
# 26722      WEZ       2             60             254           45
# 26652      WEZ       1             60             254           45
# 26653      WEZ       1             60             254           84
# 26654      WEZ       1             60             254           85
# 17922      WEZ       1              3               0           96
# 19030      WEZ       1              3               0           97
# 1393       WEZ       1              1               1         1001
# 1392       WEZ       1              1               0         1001
# 18725      WEZ       1              1               1         1002
# 18724      WEZ       1              1               0         1002
# 1531       WEZ       2              2               0         1004
# 1398       WEZ       1              2               0         1004
# 17886      WEZ       1             10               1         1007
# 17947      WEZ       2             10               1         1007
# 17931      WEZ       1              4               1         1009
# 17907      WEZ       1             10               0         1009
# 17929      WEZ       1              4               0         1009
# 18868      WEZ       1              1               0         1020
# 18869      WEZ       1              1               1         1020
# 18821      WEZ       1              1               1         1021
# 18820      WEZ       1              1               0         1021
# 17901      WEZ       1             10               1         1022
# 17919      WEZ       1             10               0         1022
# 18919      WEZ       2              2               0         1066
# 18916      WEZ       1              2               0         1066
# 17923      WEZ       1              3               0         1096
# 17924      WEZ       1              3               0         1097
# 26696      WEZ       1              0               0         1099
# 17932      WEZ       1              4               1         2043
# 17930      WEZ       1              4               0         2043
# 1400       WEZ       1              1               0         2051
# 1401       WEZ       1              1               1         2051
# 1403       WEZ       1              2               0         2052
# 17884      WEZ       1             10               1         2053
# 19034      WEZ       1              4               0         2119
# 26710      WEZ       1              4               0         2119
# 26672      WEZ       1              1               0         3032
# 1378       WEZ       1              1               1         3050
# 1377       WEZ       1              1               0         3050
# 1382       WEZ       1              1               1         3051
# 1380       WEZ       1              1               0         3051
# 1385       WEZ       1              1               2         3053
# 1381       WEZ       1              1               0         3053
# 1383       WEZ       1              1               1         3053
# 1528       WEZ       2              2               0         5050
# 1395       WEZ       1              2               0         5050
# 1396       WEZ       1              2               0         5051
# 1397       WEZ       1              2               0         5086
# 1389       WEZ       1              1               0         7036
# 18644      WEZ       1              1               0         7047
# 1460       WEZ       1             10               1         9075
# 1593       WEZ       2             10               1         9075
# 17900      WEZ       1             10               1        20050
# 17885      WEZ       1             10               1        20051
# 17949      WEZ       2             10               1        20052
# 17888      WEZ       1             10               1        20052
# 17899      WEZ       1             10               1        20053
# 17960      WEZ       2             10               1        20053
# 26698      WEZ       1              0               0        20069
# 1578       WEZ       2              0               0        21031
# 1445       WEZ       1              0               0        21031
# 1446       WEZ       1              0               0        21032
# 1579       WEZ       2              0               0        21032
# 1447       WEZ       1              0               0        21033
# 1580       WEZ       2              0               0        21033
# 1582       WEZ       2              0               0        21035
# 1450       WEZ       1              0               0        21036
# 1451       WEZ       1              0               0        21037
# 1584       WEZ       2              0               0        21037
# 26699      WEZ       1              0               0        21090
# 30903      WEZ       1              0               0        21090
# 26700      WEZ       1              0               0        21091
# 18211      WEZ       1              0               0        21120
# 18216      WEZ       2              0               0        21120
# 18217      WEZ       2              0               0        21121
# 18212      WEZ       1              0               0        21121
# 24773      WEZ       1             10               1        23002
# 24777      WEZ       2             10               1        23002
# 24778      WEZ       2             10               1        23003
# 24774      WEZ       1             10               1        23003
# 26629      WEZ       1             10               1        23008
# 26630      WEZ       2             10               1        23008
# 1463       WEZ       1             10               1        23085
# 1596       WEZ       2             10               1        23085
# 26704      WEZ       1              0               0        38003
# 26707      WEZ       1              0               0        38012
# 26708      WEZ       1              0               0        38013
#
#                                 DatapointName  Register Address  \
# 1376                     AF1 - Aussenfühler 1              1477
# 1419            Sollwert für Heizkreisbetrieb              1520
# 1509                     AF1 - Aussenfühler 1              1610
# 1410                                 Raum-Ist              1511
# 1420             Sollwert für Speicherbetrieb              1521
# 1409                                 Raum-Ist              1510
# 1414                              Vorlauf-Ist              1515
# 1413                              Vorlauf-Ist              1514
# 1412                              Vorlauf-Ist              1513
# 1532                        Warmwasser-Ist SF              1633
# 1399                        Warmwasser-Ist SF              1500
# 26715                      Warmwasser-Ist SF2             27553
# 17887                       Wärmeerzeuger-Ist             18725
# 17948                       Wärmeerzeuger-Ist             18786
# 17965        Rücklauftemperatur Wärmeerzeuger             18803
# 17904        Rücklauftemperatur Wärmeerzeuger             18742
# 1424                           WEZ-Temperatur              1525
# 1428                         Heizung Sollwert              1529
# 17902                     Drehzahl Hauptpumpe             18740
# 1429                        Speicher Sollwert              1530
# 1430                             WEZ Sollwert              1531
# 1433                 Fehlercode vom Automaten              1534
# 1435                             WEZ-Leistung              1536
# 1568                             WEZ-Leistung              1669
# 1569                        Absolute Leistung              1670
# 1436                        Absolute Leistung              1537
# 1438                               WEZ-Status              1539
# 1439                           Betriebsstatus              1540
# 26722              Coefficient of Performance             27560
# 26652              Coefficient of Performance             27490
# 26653              Sondenvorlauf-/Ansaugtemp.             27491
# 26654  Sondenrücklauf-/Verdampferoberfl.temp.             27492
# 17922         Anlage Vorlauftemperatur Heizen             18760
# 19030             Anlage Vorlauftemperatur WW             19868
# 1393                                Raum-Soll              1494
# 1392                                Raum-Soll              1493
# 18725                            Vorlauf-Soll             19563
# 18724                            Vorlauf-Soll             19562
# 1531                          Warmwasser-Soll              1632
# 1398                          Warmwasser-Soll              1499
# 17886                      Wärmeerzeuger-Soll             18724
# 17947                      Wärmeerzeuger-Soll             18785
# 17931         Sollwert Leistung Wärmeerzeuger             18769
# 17907         Sollwert Leistung Wärmeerzeuger             18745
# 17929         Sollwert Leistung Wärmeerzeuger             18767
# 18868                                   Pumpe             19706
# 18869                                   Pumpe             19707
# 18821                                 Mischer             19659
# 18820                                 Mischer             19658
# 17901                     Pumpe Wärmeerzeuger             18739
# 17919                     Pumpe Wärmeerzeuger             18757
# 18919                SLP Warmwasser-Ladepumpe             19757
# 18916                SLP Warmwasser-Ladepumpe             19754
# 17923          Anlagetemp.Soll Heizen aktuell             18761
# 17924              Anlagetemp.Soll WW aktuell             18762
# 26696          Sammelstörung Störmeldeausgang             27534
# 17932            0 - 100% aktuelle Anf. an WE             18770
# 17930            0 - 100% aktuelle Anf. an WE             18768
# 1400                 Status Heizkreisregelung              1501
# 1401                 Status Heizkreisregelung              1502
# 1403                Status Warmwasserregelung              1504
# 17884            Status Wärmeerzeugerregelung             18722
# 19034                            Führungs-WEZ             19872
# 26710                           Führungs-WEZ              27548
# 26672                          Regelstrategie             27510
# 1378                     Betriebswahl Heizung              1479
# 1377                     Betriebswahl Heizung              1478
# 1382        Normal-Raumtemperatur Heizbetrieb              1483
# 1380        Normal-Raumtemperatur Heizbetrieb              1481
# 1385          Spar-Raumtemperatur Heizbetrieb              1486
# 1381          Spar-Raumtemperatur Heizbetrieb              1482
# 1383          Spar-Raumtemperatur Heizbetrieb              1484
# 1528                  Betriebswahl Warmwasser              1629
# 1395                  Betriebswahl Warmwasser              1496
# 1396              Normal-Warmwassertemperatur              1497
# 1397                Spar-Warmwassertemperatur              1498
# 1389         Vorlauf Soll Konstantanf. Heizen              1490
# 18644        Vorlauf Soll Konstantanf. Kühlen             19482
# 1460               Betriebswahl Wärmeerzeuger              1561
# 1593               Betriebswahl Wärmeerzeuger              1694
# 17900                             Wasserdruck             18738
# 17885                               FA-Status             18723
# 17949                              Modulation             18787
# 17888                              Modulation             18726
# 17899                         Betriebsmeldung             18737
# 17960                         Betriebsmeldung             18798
# 26698        Verfügbare el. Leistung gedämpft             27536
# 1578                           MK1 HW-Ausgang              1679
# 1445                           MK1 HW-Ausgang              1546
# 1446                          YK1+ HW-Ausgang              1547
# 1579                          YK1+ HW-Ausgang              1680
# 1447                          YK1- HW-Ausgang              1548
# 1580                          YK1- HW-Ausgang              1681
# 1582                           SLP HW-Ausgang              1683
# 1450                           VA1 HW-Ausgang              1551
# 1451                           VA2 HW-Ausgang              1552
# 1584                           VA2 HW-Ausgang              1685
# 26699                       Status Smart Grid             27537
# 30903                       Status Smart Grid             31741
# 26700      Status Sollwert Erhöhung/Reduktion             27538
# 18211         Info 1 - vermutlich AVF W (VE1)             19049
# 18216      Info 1 - vermutlich DF1-1 (21-015)             19054
# 18217      Info 2 - vermutlich DF1-2 (21-018)             19055
# 18212         Info 2 - vermutlich AVF H (VE2)             19050
# 24773  Aktuelle elektr. Leistungsaufnahme WEZ             25611
# 24777  Aktuelle elektr. Leistungsaufnahme WEZ             25615
# 24778   Aktuelle therm. Leistungsaufnahme WEZ             25616
# 24774   Aktuelle therm. Leistungsaufnahme WEZ             25612
# 26629               JAZ Jahresarbeitszahl WEZ             27467
# 26630               JAZ Jahresarbeitszahl WEZ             27468
# 1463                 Emissionstest aktivieren              1564
# 1596                 Emissionstest aktivieren              1697
# 26704                      SG Mindestleistung             27542
# 26707               Smart Grid über Systembus             27545
# 26708            Auslöser Smart Grid Funktion             27546
#
#       FunctionGroup name Function name
# 1376           Allgemein     Allgemein
# 1419             Automat  FA Allgemein
# 1509           Allgemein     Allgemein
# 1410           Heizkreis   Heizkreis 2
# 1420             Automat  FA Allgemein
# 1409           Heizkreis   Heizkreis 1
# 1414           Heizkreis   Heizkreis 3
# 1413           Heizkreis   Heizkreis 2
# 1412           Heizkreis   Heizkreis 1
# 1532          Warmwasser  Warmwasser 1
# 1399          Warmwasser  Warmwasser 1
# 26715         Warmwasser  Warmwasser 1
# 17887          Wärmeerz.     Wärmeerz.
# 17948          Wärmeerz.     Wärmeerz.
# 17965          Wärmeerz.     Wärmeerz.
# 17904          Wärmeerz.     Wärmeerz.
# 1424             Automat  FA Allgemein
# 1428             Automat  FA Allgemein
# 17902          Wärmeerz.     Wärmeerz.
# 1429             Automat  FA Allgemein
# 1430             Automat  FA Allgemein
# 1433             Automat  FA Allgemein
# 1435             Automat  FA Allgemein
# 1568             Automat  FA Allgemein
# 1569             Automat  FA Allgemein
# 1436             Automat  FA Allgemein
# 1438             Automat  FA Allgemein
# 1439             Automat  FA Allgemein
# 26722            Automat  FA Allgemein
# 26652            Automat  FA Allgemein
# 26653            Automat  FA Allgemein
# 26654            Automat  FA Allgemein
# 17922       Wärmemanager  Wärmemanager
# 19030       Wärmemanager  Wärmemanager
# 1393           Heizkreis   Heizkreis 2
# 1392           Heizkreis   Heizkreis 1
# 18725          Heizkreis   Heizkreis 2
# 18724          Heizkreis   Heizkreis 1
# 1531          Warmwasser  Warmwasser 1
# 1398          Warmwasser  Warmwasser 1
# 17886          Wärmeerz.     Wärmeerz.
# 17947          Wärmeerz.     Wärmeerz.
# 17931         Kaskadenm.  Kaskadenm. 2
# 17907          Wärmeerz.  Zusatzwärme.
# 17929         Kaskadenm.  Kaskadenm. 1
# 18868          Heizkreis   Heizkreis 1
# 18869          Heizkreis   Heizkreis 2
# 18821          Heizkreis   Heizkreis 2
# 18820          Heizkreis   Heizkreis 1
# 17901          Wärmeerz.     Wärmeerz.
# 17919          Wärmeerz.  Zusatzwärme.
# 18919        Warmwasser   Warmwasser 1
# 18916        Warmwasser   Warmwasser 1
# 17923       Wärmemanager  Wärmemanager
# 17924       Wärmemanager  Wärmemanager
# 26696          Allgemein     Allgemein
# 17932         Kaskadenm.  Kaskadenm. 2
# 17930         Kaskadenm.  Kaskadenm. 1
# 1400           Heizkreis   Heizkreis 1
# 1401           Heizkreis   Heizkreis 2
# 1403          Warmwasser  Warmwasser 1
# 17884          Wärmeerz.     Wärmeerz.
# 19034         Kaskadenm.  Kaskadenm. 1
# 26710         Kaskadenm.  Kaskadenm. 1
# 26672          Heizkreis   Heizkreis 1
# 1378           Heizkreis   Heizkreis 2
# 1377           Heizkreis   Heizkreis 1
# 1382           Heizkreis   Heizkreis 2
# 1380           Heizkreis   Heizkreis 1
# 1385           Heizkreis   Heizkreis 3
# 1381           Heizkreis   Heizkreis 1
# 1383           Heizkreis   Heizkreis 2
# 1528          Warmwasser  Warmwasser 1
# 1395          Warmwasser  Warmwasser 1
# 1396          Warmwasser  Warmwasser 1
# 1397          Warmwasser  Warmwasser 1
# 1389           Heizkreis   Heizkreis 1
# 18644          Heizkreis   Heizkreis 1
# 1460           Wärmeerz.     Wärmeerz.
# 1593           Wärmeerz.     Wärmeerz.
# 17900          Wärmeerz.     Wärmeerz.
# 17885          Wärmeerz.     Wärmeerz.
# 17949          Wärmeerz.     Wärmeerz.
# 17888          Wärmeerz.     Wärmeerz.
# 17899          Wärmeerz.     Wärmeerz.
# 17960          Wärmeerz.     Wärmeerz.
# 26698          Allgemein     Allgemein
# 1578           Allgemein     Allgemein
# 1445           Allgemein     Allgemein
# 1446           Allgemein     Allgemein
# 1579           Allgemein     Allgemein
# 1447           Allgemein     Allgemein
# 1580           Allgemein     Allgemein
# 1582           Allgemein     Allgemein
# 1450           Allgemein     Allgemein
# 1451           Allgemein     Allgemein
# 1584           Allgemein     Allgemein
# 26699          Allgemein     Allgemein
# 30903          Allgemein     Allgemein
# 26700          Allgemein     Allgemein
# 18211          Allgemein     Allgemein
# 18216          Allgemein     Allgemein
# 18217          Allgemein     Allgemein
# 18212          Allgemein     Allgemein
# 24773          Wärmeerz.     Wärmeerz.
# 24777          Wärmeerz.     Wärmeerz.
# 24778          Wärmeerz.     Wärmeerz.
# 24774          Wärmeerz.     Wärmeerz.
# 26629          Wärmeerz.     Wärmeerz.
# 26630          Wärmeerz.     Wärmeerz.
# 1463           Wärmeerz.     Wärmeerz.
# 1596           Wärmeerz.     Wärmeerz.
# 26704          Allgemein     Allgemein
# 26707          Allgemein     Allgemein
# 26708          Allgemein     Allgemein

# %%
df_test.to_excel("df_out.xlsx", index=False)
